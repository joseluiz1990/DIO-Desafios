# %% [markdown]
# <a href="https://colab.research.google.com/github/joseluiz1990/DIO-Desafios/blob/main/SistemaBancario01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saldo = 0
limite = 500
extrato = ""
numero_saques = 0
LIMITE_SAQUES = 3

menu = """
Digite operação desejada:
[d] Depositar
[s] Sacar
[e] Extrato
[x] Sair
=> """

opcao = input(menu)

while opcao != "x":
  if opcao == "d":
    valor = float(input("Informe valor do depósito: "))
    if valor > 0:
      saldo += valor
      extrato += f"Depósito: R$ {valor:.2f}\n"
      print("Depósito realizado com sucesso!")
    else:
      print("Deposito falhou! Valor negativo inválido.")

  elif opcao == "s":
    if numero_saques < LIMITE_SAQUES:
      valor = float(input("Informe valor do saque: "))
      if valor <= saldo:
        if valor <= limite:
          if valor > 0:
            saldo -= valor
            extrato += f"Saque: R$ {valor:.2f}\n"
            numero_saques = numero_saques + 1
            print("Saque realizado com sucesso!")
          else:
            print("Saque falhou! Valor negativo inválido.")
        else:
          print("Saque falhou! Saque maior que limite.")
      else:
        print("Saque falhou! Saldo insuficiente.")
    else:
      print("Saque falhou! Quantidade de saques excedido.")

  elif opcao == "e":
    print(f"EXTRATO\n{extrato}")

  print(f"Saldo: R$ {saldo:.2f}")
  opcao = input(menu)

else:
  print("Operação finalizada")
# Out:
# Digite operação desejada:
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [x] Sair
# => d
# Informe valor do depósito: -100
# Deposito falhou! Valor negativo inválido.
# Saldo: R$ 0.00
#
# Digite operação desejada:
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [x] Sair
# => s
# Informe valor do saque: -100
# Saque falhou! Valor negativo inválido.
# Saldo: R$ 0.00
#
# Digite operação desejada:
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [x] Sair
# => d
# Informe valor do depósito: 5000
# Depósito realizado com sucesso!
# Saldo: R$ 5000.00
#
# Digite operação desejada:
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [x] Sair
# => s
# Informe valor do saque: -200
# Saque falhou! Valor negativo inválido.
# Saldo: R$ 5000.00
#
# Digite operação desejada:
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [x] Sair
# => s
# Informe valor do saque: 456
# Saque realizado com sucesso!
# Saldo: R$ 4544.00
#
# Digite operação desejada:
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [x] Sair
# => s
# Informe valor do saque: 600
# Saque falhou! Saque maior que limite.
# Saldo: R$ 4544.00
#
# Digite operação desejada:
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [x] Sair
# => s
# Informe valor do saque: 500
# Saque realizado com sucesso!
# Saldo: R$ 4044.00
#
# Digite operação desejada:
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [x] Sair
# => s
# Informe valor do saque: 500
# Saque realizado com sucesso!
# Saldo: R$ 3544.00
#
# Digite operação desejada:
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [x] Sair
# => s
# Saque falhou! Quantidade de saques excedido.
# Saldo: R$ 3544.00
#
# Digite operação desejada:
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [x] Sair
# => 500
# Saldo: R$ 3544.00
#
# Digite operação desejada:
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [x] Sair
# => s
# Saque falhou! Quantidade de saques excedido.
# Saldo: R$ 3544.00
#
# Digite operação desejada:
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [x] Sair
# => 500
# Saldo: R$ 3544.00
#
# Digite operação desejada:
# [d] Depositar
# [s] Sacar
# [e] Extrato
# [x] Sair
# => x
# Operação finalizada
